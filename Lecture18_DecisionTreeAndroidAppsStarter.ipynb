# %% [markdown]
# ##Setup

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T

from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

spark

# %% [markdown]
# ## load

# %%
from pyspark.sql import types as T

schema = T.StructType([
    T.StructField("ID", T.LongType(), True),                        # 'Unnamed: 0' in the file
    T.StructField("pkgname", T.StringType(), True),
    T.StructField("DevRegisteredDomain", T.IntegerType(), True),
    T.StructField("LenDescription", T.IntegerType(), True),
    T.StructField("LenWhatsNew", T.IntegerType(), True),
    T.StructField("ReviewsAverage", T.DoubleType(), True),
    T.StructField("CurrentVersion", T.IntegerType(), True),         #  small integers
    T.StructField("Genre", T.StringType(), True),
    T.StructField("ContentRating", T.StringType(), True),
    T.StructField("LastUpdated", T.IntegerType(), True),            # sample: year (e.g., 2017)
    T.StructField("LenTitle", T.IntegerType(), True),
    T.StructField("AndroidVersion", T.StringType(), True),
    T.StructField("DeveloperCategory", T.StringType(), True),

    # 0/1 flags (sample are integers)
    T.StructField("isSpamming", T.IntegerType(), True),
    T.StructField("net", T.IntegerType(), True),
    T.StructField("intent", T.IntegerType(), True),
    T.StructField("bluetooth", T.IntegerType(), True),
    T.StructField("app", T.IntegerType(), True),
    T.StructField("provider", T.IntegerType(), True),
    T.StructField("speech", T.IntegerType(), True),
    T.StructField("nfc", T.IntegerType(), True),
    T.StructField("media", T.IntegerType(), True),
    T.StructField("hardware", T.IntegerType(), True),
    T.StructField("google", T.IntegerType(), True),
    T.StructField("os", T.IntegerType(), True),
    T.StructField("CALENDAR", T.IntegerType(), True),
    T.StructField("CAMERA", T.IntegerType(), True),
    T.StructField("CONTACTS", T.IntegerType(), True),
    T.StructField("LOCATION", T.IntegerType(), True),
    T.StructField("MICROPHONE", T.IntegerType(), True),
    T.StructField("PHONE", T.IntegerType(), True),
    T.StructField("SENSORS", T.IntegerType(), True),
    T.StructField("SMS", T.IntegerType(), True),
    T.StructField("STORAGE", T.IntegerType(), True),

    # In the sample, status is 0/1
    T.StructField("status", T.IntegerType(), True),

    # Ratings(float)
    T.StructField("FourStarRatings", T.DoubleType(), True),
    T.StructField("ThreeStarRatings", T.DoubleType(), True),
    T.StructField("FiveStarRatings", T.DoubleType(), True),
    T.StructField("OneStarRatings", T.DoubleType(), True),
    T.StructField("TwoStarRatings", T.DoubleType(), True),

    T.StructField("lowest_android_version", T.StringType(), True),
    # keep as StringType to safely allow 'inf' (seen in the sample)
    T.StructField("highest_android_version", T.StringType(), True),

    T.StructField("paid", T.IntegerType(), True),
    T.StructField("file_size", T.IntegerType(), True),
    T.StructField("max_downloads_log", T.DoubleType(), True),

    # 0/1 presence flags in sample
    T.StructField("developer_email", T.IntegerType(), True),
    T.StructField("privacy_policy_link", T.IntegerType(), True),
    T.StructField("developer_address", T.IntegerType(), True),
    T.StructField("developer_website", T.IntegerType(), True),

    T.StructField("days_since_last_update", T.IntegerType(), True),
])

# %%
path = "dbfs:/FileStore/BDA_Datasets/android_corrected_permacts.csv"  

# read the file to df
     

#display(df.limit(10))
#df.printSchema()

# %%
# Drop the column Android Version columns

# %%
TARGET = "status"

# Columns that are identifiers, free text, links, or clearly non-predictive strings
EXCLUDE = {

}

# Keep only columns that exist in your df and are not the target/excluded
cols = [c for c in df.columns if c != TARGET and c not in EXCLUDE]

# Split into numeric-like vs categorical-like by Spark dtype


print("Numerical features:", num_like)
print("Categorical features:", cat_like)

# %%
# Ensure label is double and drop nulls

# Cast numeric-like to double (MLlib expects doubles)

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler

# Index categoricals like we did last time

# %%
# do you train test split and prepare evaulators

# %%
#Optional feature importance
